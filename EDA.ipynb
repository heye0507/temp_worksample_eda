# %%
from utility import *

# %% [markdown]
# # MNIST

# %%
path = '/home/jupyter/enlitic/data/mnist.pkl.gz'
x_train, y_train, x_valid, y_valid, x_test, y_test = get_data_MNIST(path)

# %%
show_batch((x_train,y_train))

# %%
show_batch((x_train,y_train),rows=4)

# %% [markdown]
# # CIFAR 100

# %%
path = '/home/jupyter/enlitic/data/cifar-100-python'
x_train_c, y_train_c, x_valid_c, y_valid_c, x_test_c, y_test_c, meta = get_data_Cifar100(path)

# %%
show_batch((x_train_c,y_train_c),dim=3,meta=meta)

# %%
show_batch((x_train_c,y_train_c),rows=4,dim=3,meta=meta)

# %% [markdown]
# # Fin
